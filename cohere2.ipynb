# %%
import warnings
warnings.filterwarnings('ignore')
import os
import gradio as gr
import torch

import tempfile
import numpy as np
import cohere
import spacy
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from pdfminer.high_level import extract_text
from nltk.tokenize.texttiling import TextTilingTokenizer

co = cohere.Client(os.environ.get("CO_API_KEY"))

nlp = spacy.load("en_core_web_sm")

from transformers import AutoTokenizer, AutoModel

# Load models
tokenizer = AutoTokenizer.from_pretrained("law-ai/InLegalBERT")
model = AutoModel.from_pretrained("law-ai/InLegalBERT")

# Initialize TextTilingTokenizer with default parameters
tiling_tokenizer = TextTilingTokenizer()

def generate_response(prompt, embeddings):
    aggregated_embedding = np.mean([np.mean(embed) for embed in embeddings])
    embedding_str = f"Embedding summary: {aggregated_embedding:.2f}"
    
    full_prompt = f"{embedding_str}\n\n{prompt}"
    
    try:
        response = co.generate(
            model="command-xlarge-nightly",
            prompt=full_prompt,
            max_tokens=300  # Increase the max tokens for a longer response
        )
        return response.generations[0].text.strip()
    
    except cohere.error.CohereError as e:
        return f"An error occurred: {str(e)}"

def extract_text_from_pdf(pdf_path):
    return extract_text(pdf_path)

def get_bert_embeddings(texts):
    embeddings_list = []

    for text in texts:
        inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=512)
        with torch.no_grad():
            outputs = model(**inputs)
        embeddings = outputs.last_hidden_state[:, 0, :].squeeze().numpy()
        embeddings_list.append(embeddings)

    return embeddings_list

def analyze_text(text):
    doc = nlp(text)
    entities = [(ent.text, ent.label_) for ent in doc.ents]
    tokens = word_tokenize(text)
    pos_tags = pos_tag(tokens)
    dependencies = [(token.text, token.dep_, token.head.text) for token in doc]
    return entities, pos_tags, dependencies

def process_pdf_and_generate_response(pdf_file, query):
    with tempfile.NamedTemporaryFile(delete=False, suffix=".pdf") as temp_file:
        with open(pdf_file, 'rb') as f:
            temp_file.write(f.read())
            temp_file_path = temp_file.name

    document_text = extract_text_from_pdf(temp_file_path)

    entities, pos_tags, dependencies = analyze_text(document_text)
    
    print("Entities:", entities)
    print("POS Tags:", pos_tags)
    print("Dependencies:", dependencies)
    
    # Segment the document text using TextTiling
    text_chunks = tiling_tokenizer.tokenize(document_text)
    
    # Process document text with InLegalBERT
    document_embeddings = get_bert_embeddings(text_chunks)
    
    # Construct prompt for LLM
    prompt = f"Given the document: '{document_text[:2000]}', answer the question: '{query}'"
    
    # Generate response using LLM
    response = generate_response(prompt, document_embeddings)
    
    return response

def chunk_long_sentence(sentence):
    words = sentence.split()
    chunks = []
    current_chunk = []
    
    for word in words:
        if len(' '.join(current_chunk + [word])) <= 512:
            current_chunk.append(word)
        else:
            chunks.append(' '.join(current_chunk))
            current_chunk = [word]
    
    if current_chunk:
        chunks.append(' '.join(current_chunk))
    
    return chunks

# Create the Gradio interface
iface = gr.Interface(
    fn=process_pdf_and_generate_response,
    inputs=[
        gr.File(label="Upload PDF Document"), 
        gr.Textbox(label="Query", placeholder="Enter your question here...")
    ],
    outputs=gr.Textbox(label="Response"),
    title="AI-Driven Research Engine for Commercial Courts",
    description="Upload a PDF document and ask a question to get a response generated based on the content of the document."
)

# Launch the interface
iface.launch(share=True)
# Out:
# Running on local URL:  http://127.0.0.1:7864
# Running on public URL: https://8018641655b708b9a2.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://8018641655b708b9a2.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Entities: [('850', 'CARDINAL'), ('SUPREME', 'ORG'), ('2022', 'DATE'), ('4', 'CARDINAL'), ('S.C.R. 850', 'CARDINAL'), ('2022', 'CARDINAL'), ('4', 'CARDINAL'), ('ANR', 'ORG'), ('2022', 'DATE'), ('SEPTEMBER 30, 2022', 'DATE'), ('M.  R.  SHAH', 'PERSON'), ('MURARI', 'GPE'), ('Arbitration', 'WORK_OF_ART'), ('1996', 'DATE'), ('1908', 'DATE'), ('XXXVIII', 'ORG'), ('Application', 'ORG'), ('Commercial  Court', 'ORG'), ('no.1', 'PRODUCT'), ('Thereafter', 'PERSON'), ('No.1', 'CARDINAL'), ('Commercial  Court', 'ORG'), ('Commercial  Court', 'ORG'), ('Order', 'ORG'), ('High  Court', 'ORG'), ('Bank', 'ORG'), ('Commercial  Court', 'ORG'), ('XXXVIII', 'ORG'), ('CPC', 'ORG'), ('the\nCourt', 'ORG'), ('decree/', 'FAC'), ('the Commercial Court', 'ORG'), ('Order', 'ORG'), ('Commercial  Court', 'ORG'), ('XXXVIII', 'ORG'), ('CPC', 'ORG'), ('Commercial  Court', 'ORG'), ('Commercial  Court', 'ORG'), ('Commercial  Courts Act', 'ORG'), ('2015', 'DATE'), ('6908', 'DATE'), ('2022', 'DATE'), ('850', 'CARDINAL'), ('SANGHI INDUSTRIES LIMITED v. RAVIN CABLES  LTD.', 'ORG'), ('ANR', 'ORG'), ('851', 'CARDINAL'), ('Order', 'ORG'), ('11.02.2022', 'CARDINAL'), ('the High Court', 'ORG'), ('Gujarat', 'GPE'), ('2021', 'DATE'), ('Vivek Chib', 'PERSON'), ('Wadhwa', 'PERSON'), ('Shaishir Divatia', 'PERSON'), ('Abhishek Kumar', 'PERSON'), ('Bikram Dwivedi', 'PERSON'), ('Shivendra Singh', 'PERSON'), ('Advs', 'ORG'), ('K. V. Viswanathan', 'PERSON'), ('Sr', 'GPE'), ('Malvika Kapila', 'PERSON'), ('Arvind Raj', 'PERSON'), ('Tanwangi Shukla', 'PERSON'), ('Krishan Kumar', 'PERSON'), ('Atul Sheopuri', 'PERSON'), ('Kartik\nSarsoonia', 'PERSON'), ('Swikiritimala', 'GPE'), ('Dubey', 'PERSON'), ('Swati', 'GPE'), ('Advs', 'ORG'), ('The Judgment of the Court', 'WORK_OF_ART'), ('M.  R.  SHAH', 'PERSON'), ('J.', 'ORG'), ('1', 'CARDINAL'), ('11.02.2022', 'DATE'), ('Gujarat', 'GPE'), ('Ahmedabad', 'GPE'), ('2021', 'DATE'), ('High Court', 'ORG'), ('Commercial  Court', 'ORG'), ('9', 'CARDINAL'), ('Arbitration and Conciliation Act', 'LAW'), ('Arbitration Act, 1996', 'LAW'), ('the Commercial Court', 'ORG'), ('1', 'CARDINAL'), ('Nos', 'PERSON'), ('02', 'DATE'), ('03', 'CARDINAL'), ('1', 'CARDINAL'), ('2', 'CARDINAL'), ('Shri K.V. Viswanathan', 'ORG'), ('1', 'CARDINAL'), ('3', 'CARDINAL'), ('three', 'CARDINAL'), ('Nos', 'PERSON'), ('02', 'DATE'), ('03', 'DATE'), ('INR', 'ORG'), ('29.31', 'CARDINAL'), ('1', 'CARDINAL'), ('19.06.2021', 'CARDINAL'), ('1', 'CARDINAL'), ('13.07.2021', 'CARDINAL'), ('INR', 'ORG'), ('1.30', 'CARDINAL'), ('21.07.2021', 'CARDINAL'), ('1', 'CARDINAL'), ('1', 'CARDINAL'), ('852', 'CARDINAL'), ('2022', 'DATE'), ('4', 'CARDINAL'), ('22.07.2021', 'CARDINAL'), ('the next\nday i.e.', 'DATE'), ('23.07.2021', 'CARDINAL'), ('1', 'CARDINAL'), ('two', 'CARDINAL'), ('Section 9 of the Arbitration Act, 1996', 'LAW'), ('438/2021', 'CARDINAL'), ('the Commercial Court', 'ORG'), ('88/2021', 'CARDINAL'), ('the Commercial Court', 'ORG'), ('88/2021', 'CARDINAL'), ('9', 'CARDINAL'), ('the Arbitration Act', 'LAW'), ('1996', 'DATE'), ('1', 'CARDINAL'), ('three', 'CARDINAL'), ('the Commercial Court', 'ORG'), ('Section', 'ORG'), ('9(ii)(e', 'CARDINAL'), ('the Arbitration Act, 1996', 'LAW'), ('the Commercial Court', 'ORG'), ('the Arbitration Act', 'LAW'), ('1996', 'DATE'), ('Nos', 'PERSON'), ('01', 'DATE'), ('02', 'CARDINAL'), ('03', 'CARDINAL'), ('the High Court', 'ORG'), ('13', 'CARDINAL'), ('Commercial  Courts Act', 'ORG'), ('2015', 'DATE'), ('the High Court', 'ORG'), ('4', 'CARDINAL'), ('the Commercial Court', 'ORG'), ('Section', 'ORG'), ('9', 'CARDINAL'), ('the Arbitration Act', 'LAW'), ('1996', 'DATE'), ('the Commercial Court', 'ORG'), ('the Commercial Court', 'ORG'), ('Section 9(ii)(e', 'LAW'), ('the Arbitration Act, 1996', 'LAW'), ('Order XXXVIII Rule 5', 'LAW'), ('CPC', 'ORG'), ('Court', 'ORG'), ('the Commercial Court', 'ORG'), ('Section 9', 'LAW'), ('Arbitration Act, 1996', 'LAW'), ('SANGHI INDUSTRIES LIMITED v. RAVIN CABLES  LTD', 'ORG'), ('ANR', 'ORG'), ('[M. R. SHAH', 'PERSON'), ('J.]\ ...
# POS Tags: [('850', 'CD'), ('SUPREME', 'NNP'), ('COURT', 'NNP'), ('REPORTS', 'NNP'), ('[', 'NN'), ('2022', 'CD'), (']', 'NN'), ('4', 'CD'), ('S.C.R', 'NNP'), ('.', '.'), ('850', 'CD'), ('[', 'JJ'), ('2022', 'CD'), (']', '$'), ('4', 'CD'), ('S.C.R', 'NNP'), ('.', '.'), ('A', 'DT'), ('B', 'NNP'), ('C', 'NNP'), ('D', 'NNP'), ('E', 'NNP'), ('F', 'NNP'), ('G', 'NNP'), ('H', 'NNP'), ('SANGHI', 'NNP'), ('INDUSTRIES', 'NNP'), ('LIMITED', 'NNP'), ('v.', 'NN'), ('RAVIN', 'NNP'), ('CABLES', 'NNP'), ('LTD.', 'NNP'), (',', ','), ('AND', 'NNP'), ('ANR', 'NNP'), ('.', '.'), ('(', '('), ('Civil', 'NNP'), ('Appeal', 'NNP'), ('No', 'NNP'), ('.', '.'), ('6908', 'CD'), ('of', 'IN'), ('2022', 'CD'), (')', ')'), ('SEPTEMBER', 'NNP'), ('30', 'CD'), (',', ','), ('2022', 'CD'), ('[', 'NN'), ('M.', 'NNP'), ('R.', 'NNP'), ('SHAH', 'NNP'), ('AND', 'NNP'), ('KRISHNA', 'NNP'), ('MURARI', 'NNP'), (',', ','), ('JJ', 'NNP'), ('.', '.'), (']', 'CC'), ('Arbitration', 'NNP'), ('and', 'CC'), ('Conciliation', 'NNP'), ('Act', 'NNP'), (',', ','), ('1996', 'CD'), ('–', 'NN'), ('s.9', 'NN'), ('–', 'NNP'), ('Code', 'NNP'), ('of', 'IN'), ('Civil', 'NNP'), ('Procedure', 'NNP'), (',', ','), ('1908', 'CD'), ('–', 'NN'), ('Or.XXXVIII', 'NNP'), (',', ','), ('r.5', 'NN'), ('–', 'NNP'), ('Application', 'NNP'), ('u/s.9', 'RB'), ('–', 'NNP'), ('Power', 'NNP'), ('of', 'IN'), ('Commercial', 'NNP'), ('Court', 'NNP'), ('–', 'NNP'), ('Appellant', 'NNP'), ('invoked', 'VBD'), ('performance', 'NN'), ('bank', 'NN'), ('guarantees', 'NNS'), ('issued', 'VBN'), ('by', 'IN'), ('respondent', 'JJ'), ('no.1', 'JJ'), ('–', 'NN'), ('Thereafter', 'NNP'), (',', ','), ('it', 'PRP'), ('invoked', 'VBD'), ('arbitration', 'NN'), ('–', 'NNP'), ('Respondent', 'NNP'), ('No.1', 'NNP'), ('filed', 'VBD'), ('application', 'NN'), ('u/s.9', 'NN'), ('before', 'IN'), ('Commercial', 'JJ'), ('Court', 'NNP'), ('regarding', 'VBG'), ('the', 'DT'), ('bank', 'NN'), ('guarantees', 'NNS'), (',', ','), ('pending', 'VBG'), ('which', 'WDT'), ('the', 'DT'), ('bank', 'NN'), ('realized', 'VBD'), ('the', 'DT'), ('payments', 'NNS'), ('under', 'IN'), ('the', 'DT'), ('bank', 'NN'), ('guarantees', 'NNS'), ('invoked', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('appellant', 'JJ'), ('–', 'NNP'), ('Commercial', 'NNP'), ('Court', 'NNP'), ('passed', 'VBD'), ('order', 'NN'), ('u/s.9', 'NN'), ('(', '('), ('ii', 'NN'), (')', ')'), ('(', '('), ('e', 'NN'), (')', ')'), ('to', 'TO'), ('secure', 'VB'), ('the', 'DT'), ('amount', 'NN'), ('in', 'IN'), ('dispute', 'NN'), ('and', 'CC'), ('directed', 'VBD'), ('the', 'DT'), ('appellant', 'NN'), ('to', 'TO'), ('deposit', 'VB'), ('the', 'DT'), ('amount', 'NN'), ('of', 'IN'), ('bank', 'NN'), ('guarantees', 'NNS'), ('–', 'JJ'), ('Order', 'NNP'), ('confirmed', 'VBN'), ('by', 'IN'), ('High', 'NNP'), ('Court', 'NNP'), ('–', 'VBD'), ('Held', 'NNP'), (':', ':'), ('Bank', 'NNP'), ('guarantees', 'NNS'), ('were', 'VBD'), ('already', 'RB'), ('invoked', 'VBN'), ('and', 'CC'), ('the', 'DT'), ('amounts', 'NNS'), ('thereunder', 'WDT'), ('were', 'VBD'), ('already', 'RB'), ('paid', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('bank', 'NN'), ('much', 'JJ'), ('prior', 'NN'), ('to', 'TO'), ('the', 'DT'), ('Commercial', 'NNP'), ('Court', 'NNP'), ('passed', 'VBD'), ('the', 'DT'), ('order', 'NN'), ('u/s.9', 'JJ'), ('–', 'NNP'), ('Unless', 'NNP'), ('and', 'CC'), ('until', 'IN'), ('the', 'DT'), ('pre-conditions', 'NNS'), ('u/Or.XXXVIII', 'JJ'), (',', ','), ('r.5', 'NN'), (',', ','), ('CPC', 'NNP'), ('were', 'VBD'), ('satisfied', 'JJ'), ('and', 'CC'), ('unless', 'IN'), ('there', 'EX'), ('were', 'VBD'), ('specific', 'JJ'), ('allegations', 'NNS'), ('with', 'IN'), ('cogent', 'JJ'), ('material', 'NN'), ('and', 'CC'), ('prima-facie', 'JJ'), ('the', 'DT'), ('Court', 'NNP'), ('was', 'VBD'), ('satisfied', 'VBN'), ('that', 'IN'), ('the', 'DT'), ('appellant', 'NN'), ('was', 'VBD'), ('likely', 'JJ'), ('to', 'TO'), ('defeat', 'VB'), ('the', 'DT'), ('decree/', 'NN'), ('award', 'NN'), ('that', 'WDT'), ('may', 'MD'), ('be', 'VB'), ('passed', 'VBN'), ('by', 'I ...
# Dependencies: [('850', 'nummod', 'REPORTS'), ('\n\n', 'dep', '850'), ('SUPREME', 'amod', 'COURT'), (' ', 'dep', 'SUPREME'), ('COURT', 'compound', 'REPORTS'), (' ', 'dep', 'COURT'), ('REPORTS', 'ROOT', 'REPORTS'), ('\n\n', 'dep', 'REPORTS'), ('[', 'punct', 'REPORTS'), ('2022', 'nmod', 'S.C.R.'), (']', 'punct', 'S.C.R.'), ('4', 'nummod', 'S.C.R.'), ('S.C.R.', 'appos', 'REPORTS'), ('850', 'nummod', 'S.C.R.'), ('\n\n', 'dep', '850'), ('[', 'punct', 'REPORTS'), ('2022', 'nmod', 'LIMITED'), (']', 'punct', '4'), ('4', 'prep', '2022'), ('S.C.R.', 'compound', 'A'), ('\n\n', 'dep', 'S.C.R.'), ('A', 'compound', 'B'), ('\n\n', 'dep', 'A'), ('B', 'npadvmod', '2022'), ('\n\n', 'dep', 'B'), ('C', 'compound', 'D'), ('\n\n', 'dep', 'C'), ('D', 'npadvmod', '2022'), ('\n\n', 'dep', 'D'), ('E', 'nmod', 'H'), ('\n\n', 'dep', 'E'), ('F', 'compound', 'H'), ('\n\n', 'dep', 'F'), ('G', 'compound', 'H'), ('\n\n', 'dep', 'G'), ('H', 'nmod', 'D'), ('\n\n', 'dep', 'H'), ('SANGHI', 'compound', 'LIMITED'), (' ', 'dep', 'SANGHI'), ('INDUSTRIES', 'compound', 'LIMITED'), (' ', 'dep', 'INDUSTRIES'), ('LIMITED', 'appos', 'REPORTS'), ('\n', 'dep', 'LIMITED'), ('v.', 'prep', 'LIMITED'), ('\n\n', 'dep', 'v.'), ('RAVIN', 'compound', 'LTD'), (' ', 'dep', 'RAVIN'), ('CABLES', 'compound', 'LTD'), (' ', 'dep', 'CABLES'), ('LTD', 'pobj', 'v.'), ('.', 'conj', 'LIMITED'), (',', 'punct', 'LIMITED'), ('AND', 'cc', 'LIMITED'), ('ANR', 'conj', 'LIMITED'), ('.', 'punct', 'REPORTS'), ('\n\n', 'dep', '.'), ('(', 'punct', 'No'), ('Civil', 'compound', 'Appeal'), ('Appeal', 'compound', 'No'), ('No', 'ROOT', 'No'), ('.', 'punct', 'No'), ('6908', 'npadvmod', 'No'), ('of', 'prep', '6908'), ('2022', 'pobj', 'of'), (')', 'punct', 'No'), ('\n', 'dep', ')'), ('SEPTEMBER', 'appos', 'No'), ('30', 'nummod', 'SEPTEMBER'), (',', 'punct', 'SEPTEMBER'), ('2022', 'nummod', 'SEPTEMBER'), ('\n\n', 'dep', '2022'), ('[', 'nmod', 'MURARI'), ('M.', 'nmod', 'SHAH'), (' ', 'dep', 'M.'), ('R.', 'compound', 'SHAH'), (' ', 'dep', 'R.'), ('SHAH', 'nmod', 'MURARI'), ('AND', 'cc', 'SHAH'), (' ', 'dep', 'AND'), ('KRISHNA', 'compound', 'MURARI'), (' ', 'dep', 'KRISHNA'), ('MURARI', 'nsubj', 'r.5'), (',', 'punct', 'MURARI'), (' ', 'dep', ','), ('JJ', 'appos', 'MURARI'), ('.', 'punct', 'MURARI'), (']', 'punct', 'MURARI'), ('\n\n', 'dep', ']'), ('Arbitration', 'appos', 'MURARI'), (' ', 'dep', 'Arbitration'), ('and', 'cc', 'Arbitration'), (' ', 'dep', 'and'), ('Conciliation', 'compound', 'Act'), (' ', 'dep', 'Conciliation'), ('Act', 'conj', 'Arbitration'), (',', 'punct', 'Act'), (' ', 'dep', ','), ('1996', 'nummod', 'Arbitration'), (' ', 'dep', '1996'), ('–', 'punct', 'MURARI'), (' ', 'dep', '–'), ('s.9', 'punct', 'MURARI'), (' ', 'dep', 's.9'), ('–', 'punct', 'MURARI'), (' ', 'dep', '–'), ('Code', 'appos', 'MURARI'), (' ', 'dep', 'Code'), ('of', 'prep', 'Code'), (' ', 'dep', 'of'), ('Civil', 'compound', 'Procedure'), ('\n', 'dep', 'Civil'), ('Procedure', 'pobj', 'of'), (',', 'punct', 'MURARI'), (' ', 'dep', ','), ('1908', 'nummod', 'XXXVIII'), (' ', 'dep', '1908'), ('–', 'punct', '1908'), (' ', 'dep', '–'), ('Or', 'cc', '1908'), ('.', 'compound', 'XXXVIII'), ('XXXVIII', 'appos', 'MURARI'), (',', 'punct', 'MURARI'), (' ', 'dep', ','), ('r.5', 'ccomp', 'invoked'), (' ', 'dep', 'r.5'), ('–', 'punct', 'r.5'), (' ', 'dep', '–'), ('Application', 'compound', 'u'), (' ', 'dep', 'Application'), ('u', 'attr', 'r.5'), ('/', 'punct', 'u'), ('s.9', 'punct', 'u'), (' ', 'dep', 's.9'), ('–', 'punct', 'u'), (' ', 'dep', '–'), ('Power', 'appos', 'u'), (' ', 'dep', 'Power'), ('of', 'prep', 'Power'), ('\n', 'dep', 'of'), ('Commercial', 'compound', 'Court'), (' ', 'dep', 'Commercial'), ('Court', 'pobj', 'of'), (' ', 'dep', 'Court'), ('–', 'punct', 'Court'), (' ', 'dep', '–'), ('Appellant', 'nmod', 'guarantees'), (' ', 'dep', 'Appellant'), ('invoked', 'amod', 'guarantees'), (' ', 'dep', 'invoked'), ('performance', 'compound', 'bank'), (' ', 'dep', 'performance'), ('bank', 'compound', 'guarantees'), ('\n', 'dep', 'bank'), ('guarantees',  ...
